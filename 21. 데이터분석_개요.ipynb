# %% [markdown]
# #### 데이터분석 라이브러리
#
# #### 1. Python의 주요 데이터분석 라이브러리(패키지)
#
# > 1. `numpy` : 데이터분석의 기본적인 기능을 제공, 특히 `벡터와행렬`연산 관련 기능을 제공
# > 2. `pandas` : 1차원 자료구조(`Series`)와 2차원자료구조(`DataFrame`)를 이용해서 데이터분석에 우수한 성능을 발휘한다. 대용량의 데이터를 보다 빠르게 처리할 수 있도록 지원한다.
# > 3. `matploglib` : 데이터 분석 결과에 대한 `시각화를 빠르고 직관적으로 수행`한다.
#
# #### 2. Package설치 방법
# > * `pip install numpy`
# > * `pip install pandas`
# > * `pip install matplotlib`
#
# #### 3. 설치된 패키목록 보기
# > * `pip list` or `conda list`
#
# #### 4. 참고 사이트
# * https://numpy.org
# * https://pandas.pydata.org
# * https://matplotlib.org

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2.3.3 in d:\lsk\pjt_py\.venv\lib\site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\lsk\pjt_py\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\lsk\pjt_py\.venv\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in d:\lsk\pjt_py\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    -------------------------- ------------- 6.6/10.0 MB 33.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 23.9 MB/s eta 0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: D:\LSK\pjt_py\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# ! conda list

# %% [markdown]
# #### %매직명령어
#
# * %pwd
# * %ls
# * %who or %whos
# * %hist
# * `%matpotlib` : 그래프출력을 웹에 완성된 형태로 출력할 것인지 인터렉티브형태로 출력할 것인 여부

# %%
import numpy as np
import pandas as pd
# import matplot
import matplotlib.pyplot as plt

# %whos
# Out:
# Variable             Type      Data/Info
# ----------------------------------------
# np                   module    <module 'numpy' from 'D:\<...>ges\\numpy\\__init__.py'>
# pd                   module    <module 'pandas' from 'D:<...>es\\pandas\\__init__.py'>
# plt                  module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# pydev_jupyter_vars   module    <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>

# %%
# print(dir(np))
print()
print(dir(pd))
print()
# print(dir(matplotlib))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'col', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'describe_option', 'errors', 'eval', 'factorize', 'from_dummies', 'get_dummies', 'get_option', 'infer_freq', 'interval_range', 'io', 'isna', 'isnull', 'json_normalize', 'lreshape', 'melt', 'merge', 'merge_asof', 'merge_ordered', 'notna', 'notnull', 'offsets', 'option_context', 'options', 'pandas', 'period_range', 'pivot', 'pivot_table', 'plotting', 'qcut', 'read_clipboard', 'read_csv', 'read_excel', 'read_feather', 'read_fwf', 'read_hdf', 'read_html', 'read_iceberg', 'read_json', 'read_orc', 'read_parquet', 'read_pickle', 'read_sas', 'read_spss', 'read_sql', 'read_sql_query', 'read_sql_table', 'read_stata', 'read_table', 'read_xml', 'reset_option', 'set_eng_float_format', 'set_option', 'show_versions', 'test', 'testing', 'timedelta_range', 'to_datetime', 'to_numeric', 'to_pickle', 'to_timedelta', 'tseries', 'unique', 'util', 'wide_to_long']

# %%
# A. numpy

# 1. 난수발생
# print(dir(np.random))

data = np.random.rand()
print(data, type(data))

data = np.random.rand(50)
print(data, type(data))
# Out:
# 0.20347992884024657 <class 'float'>
# [0.46973624 0.31104563 0.52904489 0.32302636 0.92318622 0.19492514
#  0.2757347  0.52994977 0.08138625 0.22673793 0.39060708 0.14161455
#  0.26328396 0.54046555 0.22798218 0.7202443  0.28647229 0.62735425
#  0.42214172 0.60163712 0.7555482  0.76086875 0.59165425 0.51519392
#  0.39673486 0.7502446  0.24374328 0.20957957 0.46111671 0.86082246
#  0.9216396  0.96495102 0.52886807 0.15925417 0.69359153 0.93702599
#  0.20557309 0.51798759 0.49606072 0.06972647 0.44692591 0.6333688
#  0.36654901 0.8751405  0.18864788 0.71487657 0.49915553 0.65694391
#  0.17137373 0.43791317] <class 'numpy.ndarray'>

# %%
# B. pandas
# 1. 1차원 자료 : Series

data = np.random.rand(50)

s = pd.Series(data)
print(s, type(s))
# Out:
# 0     0.079648
# 1     0.117085
# 2     0.060340
# 3     0.451545
# 4     0.741280
# 5     0.313769
# 6     0.601366
# 7     0.792914
# 8     0.591800
# 9     0.361029
# 10    0.347803
# 11    0.533541
# 12    0.854245
# 13    0.024539
# 14    0.130771
# 15    0.142053
# 16    0.316069
# 17    0.863409
# 18    0.512267
# 19    0.681497
# 20    0.624645
# 21    0.999680
# 22    0.495713
# 23    0.831418
# 24    0.611940
# 25    0.836602
# 26    0.570741
# 27    0.717709
# 28    0.286784
# 29    0.756711
# 30    0.455600
# 31    0.268291
# 32    0.010148
# 33    0.514670
# 34    0.296586
# 35    0.543142
# 36    0.078758
# 37    0.687094
# 38    0.899494
# 39    0.074803
# 40    0.630077
# 41    0.645468
# 42    0.882978
# 43    0.055087
# 44    0.540682
# 45    0.635511
# 46    0.957647
# 47    0.052030
# 48    0.486366
# 49    0.591667
# dtype: float64 <class 'pandas.core.series.Series'>

# %%
# %matplotlib inline
# 시각화(pandas 고유기능으로 시각화) - ndarray로 시각화

s.plot()
# Out:
# <AxesSubplot:>

# %%
# 2. 2차원 자료 : DataFrame

df = pd.DataFrame(data)
print(df, type(df))

display(df, type(df))
# Out:
#            0
# 0   0.079648
# 1   0.117085
# 2   0.060340
# 3   0.451545
# 4   0.741280
# 5   0.313769
# 6   0.601366
# 7   0.792914
# 8   0.591800
# 9   0.361029
# 10  0.347803
# 11  0.533541
# 12  0.854245
# 13  0.024539
# 14  0.130771
# 15  0.142053
# 16  0.316069
# 17  0.863409
# 18  0.512267
# 19  0.681497
# 20  0.624645
# 21  0.999680
# 22  0.495713
# 23  0.831418
# 24  0.611940
# 25  0.836602
# 26  0.570741
# 27  0.717709
# 28  0.286784
# 29  0.756711
# 30  0.455600
# 31  0.268291
# 32  0.010148
# 33  0.514670
# 34  0.296586
# 35  0.543142
# 36  0.078758
# 37  0.687094
# 38  0.899494
# 39  0.074803
# 40  0.630077
# 41  0.645468
# 42  0.882978
# 43  0.055087
# 44  0.540682
# 45  0.635511
# 46  0.957647
# 47  0.052030
# 48  0.486366
# 49  0.591667 <class 'pandas.core.frame.DataFrame'>
#            0
# 0   0.079648
# 1   0.117085
# 2   0.060340
# 3   0.451545
# 4   0.741280
# 5   0.313769
# 6   0.601366
# 7   0.792914
# 8   0.591800
# 9   0.361029
# 10  0.347803
# 11  0.533541
# 12  0.854245
# 13  0.024539
# 14  0.130771
# 15  0.142053
# 16  0.316069
# 17  0.863409
# 18  0.512267
# 19  0.681497
# 20  0.624645
# 21  0.999680
# 22  0.495713
# 23  0.831418
# 24  0.611940
# 25  0.836602
# 26  0.570741
# 27  0.717709
# 28  0.286784
# 29  0.756711
# 30  0.455600
# 31  0.268291
# 32  0.010148
# 33  0.514670
# 34  0.296586
# 35  0.543142
# 36  0.078758
# 37  0.687094
# 38  0.899494
# 39  0.074803
# 40  0.630077
# 41  0.645468
# 42  0.882978
# 43  0.055087
# 44  0.540682
# 45  0.635511
# 46  0.957647
# 47  0.052030
# 48  0.486366
# 49  0.591667
# pandas.core.frame.DataFrame

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1864\3380326488.py in <module>
# ----> 1 df.plot()
#
# NameError: name 'df' is not defined

# %%
# numpy로 랜덤하게 10*3열의 2차원배열(행렬 만들기)

data = np.random.rand(10, 3)
print(data, type(data))
# Out:
# [[0.93055385 0.96156219 0.47770666]
#  [0.56312356 0.46863585 0.6350502 ]
#  [0.49409613 0.79465484 0.16818093]
#  [0.78772448 0.45174878 0.416173  ]
#  [0.34933164 0.04301002 0.86249989]
#  [0.13071568 0.6249814  0.89590084]
#  [0.61787411 0.33911039 0.90903753]
#  [0.64754875 0.96870428 0.68433704]
#  [0.35831555 0.68879138 0.05476829]
#  [0.23365061 0.16917045 0.47109785]] <class 'numpy.ndarray'>

# %%
df = pd.DataFrame(data)
display(df, type(df))
# Out:
#           0         1         2
# 0  0.930554  0.961562  0.477707
# 1  0.563124  0.468636  0.635050
# 2  0.494096  0.794655  0.168181
# 3  0.787724  0.451749  0.416173
# 4  0.349332  0.043010  0.862500
# 5  0.130716  0.624981  0.895901
# 6  0.617874  0.339110  0.909038
# 7  0.647549  0.968704  0.684337
# 8  0.358316  0.688791  0.054768
# 9  0.233651  0.169170  0.471098
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(data, columns=['2018','2019','2020'])
display(df)
# Out:
#        2018      2019      2020
# 0  0.930554  0.961562  0.477707
# 1  0.563124  0.468636  0.635050
# 2  0.494096  0.794655  0.168181
# 3  0.787724  0.451749  0.416173
# 4  0.349332  0.043010  0.862500
# 5  0.130716  0.624981  0.895901
# 6  0.617874  0.339110  0.909038
# 7  0.647549  0.968704  0.684337
# 8  0.358316  0.688791  0.054768
# 9  0.233651  0.169170  0.471098

# %%
# 2차원 자료로 시각화
df.plot()
# Out:
# <AxesSubplot:>

# %%
# bar
df.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# barh

df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# area

df.plot(kind = 'area')
df.plot(kind = 'area', stacked = False)
# Out:
# <AxesSubplot:>

# %%
# pie
s = pd.Series(data=np.random.rand(5), index = [2015,2016,2017,2018,2019])
s.plot(kind = 'pie', fontsize=11, title = 'sales test', figsize=(10,5), autopct = "%.2f%%")
# Out:
# <AxesSubplot:title={'center':'sales test'}, ylabel='None'>
